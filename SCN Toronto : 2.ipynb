# %%
import urllib.request
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
req = urllib.request.urlopen(url)
article = req.read().decode()

# %%
soup = BeautifulSoup(article, 'html.parser')
table = soup.find('table', class_='sortable')

# %%
#headings
ths = table.find_all('th')
headings = [th.text.strip() for th in ths]

#create dataframe
neighbourhoods = pd.DataFrame(columns=headings)
neighbourhoods

# scrape rows into dataframe
for tr in table.find_all('tr'):
    tds = tr.find_all('td')
    if not tds:
        continue                            #skips first row with headings
    pc, b, n = [td.text.strip() for td in tds]
    if b!="Not assigned":
        neighbourhoods = neighbourhoods.append({'Postcode': pc, 'Borough': b, 'Neighbourhood': n}, ignore_index=True)

neighbourhoods.head()
# Out:
#   Postal code           Borough Neighborhood  \
# 0         NaN        North York          NaN
# 1         NaN        North York          NaN
# 2         NaN  Downtown Toronto          NaN
# 3         NaN        North York          NaN
# 4         NaN  Downtown Toronto          NaN
#
#                                   Neighbourhood Postcode
# 0                                     Parkwoods      M3A
# 1                              Victoria Village      M4A
# 2                    Regent Park / Harbourfront      M5A
# 3             Lawrence Manor / Lawrence Heights      M6A
# 4  Queen's Park / Ontario Provincial Government      M7A

# %%
neighbourhoods['Neighbourhood'] = neighbourhoods.groupby('Postcode')['Neighbourhood'].transform(lambda x: "%s" % ', '.join(x)).values
neighbourhoods = neighbourhoods.drop_duplicates().reset_index(drop=True)
neighbourhoods.head()
# Out:
#   Postal code           Borough Neighborhood  \
# 0         NaN        North York          NaN
# 1         NaN        North York          NaN
# 2         NaN  Downtown Toronto          NaN
# 3         NaN        North York          NaN
# 4         NaN  Downtown Toronto          NaN
#
#                                   Neighbourhood Postcode
# 0                                     Parkwoods      M3A
# 1                              Victoria Village      M4A
# 2                    Regent Park / Harbourfront      M5A
# 3             Lawrence Manor / Lawrence Heights      M6A
# 4  Queen's Park / Ontario Provincial Government      M7A

# %%
neighbourhoods['Neighbourhood'].replace("Not assigned", neighbourhoods['Borough'], inplace=True)
neighbourhoods.head()
# Out:
#   Postal code           Borough Neighborhood  \
# 0         NaN        North York          NaN
# 1         NaN        North York          NaN
# 2         NaN  Downtown Toronto          NaN
# 3         NaN        North York          NaN
# 4         NaN  Downtown Toronto          NaN
#
#                                   Neighbourhood Postcode
# 0                                     Parkwoods      M3A
# 1                              Victoria Village      M4A
# 2                    Regent Park / Harbourfront      M5A
# 3             Lawrence Manor / Lawrence Heights      M6A
# 4  Queen's Park / Ontario Provincial Government      M7A

# %%
neighbourhoods.shape
# Out:
# (103, 5)

# %%
geo_df = pd.read_csv('https://cocl.us/Geospatial_data')
geo_df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
result = pd.merge(neighbourhoods, geo_df, how='left',
        left_on='Postcode', right_on='Postal Code', validate="1:1")
result.drop(labels='Postal Code', axis=1, inplace=True)
result.head()
# Out:
#   Postal code           Borough Neighborhood  \
# 0         NaN        North York          NaN
# 1         NaN        North York          NaN
# 2         NaN  Downtown Toronto          NaN
# 3         NaN        North York          NaN
# 4         NaN  Downtown Toronto          NaN
#
#                                   Neighbourhood Postcode   Latitude  Longitude
# 0                                     Parkwoods      M3A  43.753259 -79.329656
# 1                              Victoria Village      M4A  43.725882 -79.315572
# 2                    Regent Park / Harbourfront      M5A  43.654260 -79.360636
# 3             Lawrence Manor / Lawrence Heights      M6A  43.718518 -79.464763
# 4  Queen's Park / Ontario Provincial Government      M7A  43.662301 -79.389494

# %%
result
# Out:
#     Postal code           Borough Neighborhood  \
# 0           NaN        North York          NaN
# 1           NaN        North York          NaN
# 2           NaN  Downtown Toronto          NaN
# 3           NaN        North York          NaN
# 4           NaN  Downtown Toronto          NaN
# 5           NaN         Etobicoke          NaN
# 6           NaN       Scarborough          NaN
# 7           NaN        North York          NaN
# 8           NaN         East York          NaN
# 9           NaN  Downtown Toronto          NaN
# 10          NaN        North York          NaN
# 11          NaN         Etobicoke          NaN
# 12          NaN       Scarborough          NaN
# 13          NaN        North York          NaN
# 14          NaN         East York          NaN
# 15          NaN  Downtown Toronto          NaN
# 16          NaN              York          NaN
# 17          NaN         Etobicoke          NaN
# 18          NaN       Scarborough          NaN
# 19          NaN      East Toronto          NaN
# 20          NaN  Downtown Toronto          NaN
# 21          NaN              York          NaN
# 22          NaN       Scarborough          NaN
# 23          NaN         East York          NaN
# 24          NaN  Downtown Toronto          NaN
# 25          NaN  Downtown Toronto          NaN
# 26          NaN       Scarborough          NaN
# 27          NaN        North York          NaN
# 28          NaN        North York          NaN
# 29          NaN         East York          NaN
# ..          ...               ...          ...
# 73          NaN   Central Toronto          NaN
# 74          NaN   Central Toronto          NaN
# 75          NaN      West Toronto          NaN
# 76          NaN       Mississauga          NaN
# 77          NaN         Etobicoke          NaN
# 78          NaN       Scarborough          NaN
# 79          NaN   Central Toronto          NaN
# 80          NaN  Downtown Toronto          NaN
# 81          NaN      West Toronto          NaN
# 82          NaN       Scarborough          NaN
# 83          NaN   Central Toronto          NaN
# 84          NaN  Downtown Toronto          NaN
# 85          NaN       Scarborough          NaN
# 86          NaN   Central Toronto          NaN
# 87          NaN  Downtown Toronto          NaN
# 88          NaN         Etobicoke          NaN
# 89          NaN         Etobicoke          NaN
# 90          NaN       Scarborough          NaN
# 91          NaN  Downtown Toronto          NaN
# 92          NaN  Downtown Toronto          NaN
# 93          NaN         Etobicoke          NaN
# 94          NaN         Etobicoke          NaN
# 95          NaN       Scarborough          NaN
# 96          NaN  Downtown Toronto          NaN
# 97          NaN  Downtown Toronto          NaN
# 98          NaN         Etobicoke          NaN
# 99          NaN  Downtown Toronto          NaN
# 100         NaN      East Toronto          NaN
# 101         NaN         Etobicoke          NaN
# 102         NaN         Etobicoke          NaN
#
#                                          Neighbourhood Postcode   Latitude  \
# 0                                            Parkwoods      M3A  43.753259
# 1                                     Victoria Village      M4A  43.725882
# 2                           Regent Park / Harbourfront      M5A  43.654260
# 3                    Lawrence Manor / Lawrence Heights      M6A  43.718518
# 4         Queen's Park / Ontario Provincial Government      M7A  43.662301
# 5                                     Islington Avenue      M9A  43.667856
# 6                                      Malvern / Rouge      M1B  43.806686
# 7                                            Don Mills      M3B  43.745906
# 8                     Parkview Hill / Woodbine Gardens      M4B  43.706397
# 9                             Garden District, Ryerson      M5B  43.657162
# 10                                           Glencairn      M6B  43.709577
# 11   West Deane Park / Princess Gardens / Martin Gr...      M9B  43.650943
# 12            Rouge Hill / Port Union / Highland Creek      M1C  43.784535
# 13                                           Don Mills      M3C  43.725900
# 14                                    Woodbine Heights      M4C  43.695344
# 15                                      St. James Town      M5C  43.651494
# 16                                  Humewood-Cedarvale      M6C  43.693781
# 17   Eringate / Bloordale Gardens / Old Burnhamthor...      M9C  43.643515
# 18                 Guildwood / Morningside / West Hill      M1E  43.763573
# 19                                         The Beaches      M4E  43.676357
# 20                                         Berczy Park      M5E  43.644771
# 21                                 Caledonia-Fairbanks      M6E  43.689026
# 22                                              Woburn      M1G  43.770992
# 23                                             Leaside      M4G  43.709060
# 24                                  Central Bay Street      M5G  43.657952
# 25                                            Christie      M6G  43.669542
# 26                                           Cedarbrae      M1H  43.773136
# 27                                   Hillcrest Village      M2H  43.803762
# 28   Bathurst Manor / Wilson Heights / Downsview North      M3H  43.754328
# 29                                    Thorncliffe Park      M4H  43.705369
# ..                                                 ...      ...        ...
# 73                                  North Toronto West      M4R  43.715383
# 74               The Annex / North Midtown / Yorkville      M5R  43.672710
# 75                             Parkdale / Roncesvalles      M6R  43.648960
# 76               Canada Post Gateway Processing Centre      M7R  43.636966
# 77   Kingsview Village / St. Phillips / Martin Grov...      M9R  43.688905
# 78                                           Agincourt      M1S  43.794200
# 79                                          Davisville      M4S  43.704324
# 80                     University of Toronto / Harbord      M5S  43.662696
# 81                                 Runnymede / Swansea      M6S  43.651571
# 82           Clarks Corners / Tam O'Shanter / Sullivan      M1T  43.781638
# 83                        Moore Park / Summerhill East      M4T  43.689574
# 84         Kensington Market / Chinatown / Grange Park      M5T  43.653206
# 85   Milliken / Agincourt North / Steeles East / L'...      M1V  43.815252
# 86   Summerhill West / Rathnelly / South Hill / For...      M4V  43.686412
# 87   CN Tower / King and Spadina / Railway Lands / ...      M5V  43.628947
# 88      New Toronto / Mimico South / Humber Bay Shores      M8V  43.605647
# 89   South Steeles / Silverstone / Humbergate / Jam...      M9V  43.739416
# 90                      Steeles West / L'Amoreaux West      M1W  43.799525
# 91                                            Rosedale      M4W  43.679563
# 92                                      Stn A PO Boxes      M5W  43.646435
# 93                             Alderwood / Long Branch      M8W  43.602414
# 94                                           Northwest      M9W  43.706748
# 95                                         Upper Rouge      M1X  43.836125
# 96                        St. James Town / Cabbagetown      M4X  43.667967
# 97             First Canadian Place / Underground city      M5X  43.648429
# 98    The Kingsway / Montgomery Road  / Old Mill North      M8X  43.653654
# 99                                Church and Wellesley      M4Y  43.665860
# 100              Business reply mail Processing CentrE      M7Y  43.662744
# 101  Old Mill South / King's Mill Park / Sunnylea /...      M8Y  43.636258
# 102  Mimico NW / The Queensway West / South of Bloo...      M8Z  43.628841
#
#      Longitude
# 0   -79.329656
# 1   -79.315572
# 2   -79.360636
# 3   -79.464763
# 4   -79.389494
# 5   -79.532242
# 6   -79.194353
# 7   -79.352188
# 8   -79.309937
# 9   -79.378937
# 10  -79.445073
# 11  -79.554724
# 12  -79.160497
# 13  -79.340923
# 14  -79.318389
# 15  -79.375418
# 16  -79.428191
# 17  -79.577201
# 18  -79.188711
# 19  -79.293031
# 20  -79.373306
# 21  -79.453512
# 22  -79.216917
# 23  -79.363452
# 24  -79.387383
# 25  -79.422564
# 26  -79.239476
# 27  -79.363452
# 28  -79.442259
# 29  -79.349372
# ..         ...
# 73  -79.405678
# 74  -79.405678
# 75  -79.456325
# 76  -79.615819
# 77  -79.554724
# 78  -79.262029
# 79  -79.388790
# 80  -79.400049
# 81  -79.484450
# 82  -79.304302
# 83  -79.383160
# 84  -79.400049
# 85  -79.284577
# 86  -79.400049
# 87  -79.394420
# 88  -79.501321
# 89  -79.588437
# 90  -79.318389
# 91  -79.377529
# 92  -79.374846
# 93  -79.543484
# 94  -79.594054
# 95  -79.205636
# 96  -79.367675
# 97  -79.382280
# 98  -79.506944
# 99  -79.383160
# 100 -79.321558
# 101 -79.498509
# 102 -79.520999
#
# [103 rows x 7 columns]

# %%
result.shape
# Out:
# (103, 7)
